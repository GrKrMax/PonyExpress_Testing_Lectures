# %%
pip install allure-pytest

# %%
pip install pillow

# %%
import PIL

# %%
from PIL import Image

# %%
img = Image.open(r'C:\Users\Professional\Desktop\PONY\Снимок.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=567x447 at 0x16E1B8C7A30>

# %%
a = 'asdfasdf'
a[0:2]
# Out:
# 'as'

# %%
import allure

# %%
allure.step?

# %%
def test_1():
    try:
        func_1()
        func_2()
    except:
        assert 0, 'message'
